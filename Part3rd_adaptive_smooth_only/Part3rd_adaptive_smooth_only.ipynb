# %% [markdown]
# # Adaptive Smooth FixMatch (new method) only — CIFAR-10-40
#
# This notebook runs the adaptive_smooth method on CIFAR-10-40.
# Outputs removed; re-run cells in a Jupyter environment to generate outputs.

# %%
import os
os.makedirs('/kaggle/working/checkpoints_adaptive_smooth', exist_ok=True)
print("Adaptive Smooth notebook loaded successfully.")
